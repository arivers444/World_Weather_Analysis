# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as inline
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kupino
# Processing Record 2 of Set 1 | port maria
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | luderitz
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | okha
# Processing Record 12 of Set 1 | aktas
# Processing Record 13 of Set 1 | tiznit
# Processing Record 14 of Set 1 | shimoda
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | flinders
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | necochea
# Processing Record 20 of Set 1 | kahului
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | ulety
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | inongo
# Processing Record 26 of Set 1 | nabire
# Processing Record 27 of Set 1 | touros
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 31 of Set 1 | svay rieng
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | rio grande
# Processing Record 34 of Set 1 | baculin
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | comodoro rivadavia
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | gamba
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | penzance
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | camacha
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | aksarka
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | fare
# Processing Record 8 of Set 2 | zhigansk
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | sokoni
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | kamenka
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | adrar
# Processing Record 16 of Set 2 | yamada
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | whitehorse
# Processing Record 23 of Set 2 | oranjestad
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | aasiaat
# Processing Record 26 of Set 2 | kenora
# Processing Record 27 of Set 2 | mariinsk
# Processing Record 28 of Set 2 | honiara
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | greiz
# Processing Record 32 of Set 2 | sungai petani
# Processing Record 33 of Set 2 | altay
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 2 | benque viejo
# City not found. Skipping...
# Processing Record 40 of Set 2 | neiafu
# Processing Record 41 of Set 2 | palimbang
# Processing Record 42 of Set 2 | ambon
# Processing Record 43 of Set 2 | ugoofaaru
# Processing Record 44 of Set 2 | klaksvik
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | olinda
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | garissa
# Processing Record 1 of Set 3 | poya
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | susaki
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | nador
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | latung
# Processing Record 8 of Set 3 | dhidhdhoo
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | madang
# Processing Record 11 of Set 3 | barvinkove
# Processing Record 12 of Set 3 | pangkalanbuun
# Processing Record 13 of Set 3 | san salvo
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | jinxiang
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | karancslapujto
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | alice town
# Processing Record 23 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | olga
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | sinnamary
# Processing Record 28 of Set 3 | shibarghan
# City not found. Skipping...
# Processing Record 29 of Set 3 | chenghai
# Processing Record 30 of Set 3 | gdov
# Processing Record 31 of Set 3 | krasnokamensk
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 3 | selfoss
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | det udom
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | griffith
# Processing Record 39 of Set 3 | littleton
# Processing Record 40 of Set 3 | leh
# Processing Record 41 of Set 3 | yulara
# Processing Record 42 of Set 3 | imeni poliny osipenko
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | nylstroom
# City not found. Skipping...
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | sorland
# Processing Record 47 of Set 3 | goderich
# Processing Record 48 of Set 3 | north bend
# Processing Record 49 of Set 3 | severodvinsk
# Processing Record 50 of Set 3 | kyra
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | lakselv
# Processing Record 4 of Set 4 | lumphat
# Processing Record 5 of Set 4 | corpus christi
# Processing Record 6 of Set 4 | mumbwa
# Processing Record 7 of Set 4 | shiraz
# Processing Record 8 of Set 4 | ahar
# Processing Record 9 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 4 | tocache
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | padang
# Processing Record 14 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 4 | eyrarbakki
# Processing Record 16 of Set 4 | boysun
# Processing Record 17 of Set 4 | kesennuma
# City not found. Skipping...
# Processing Record 18 of Set 4 | pontianak
# Processing Record 19 of Set 4 | gao
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | mogadishu
# Processing Record 24 of Set 4 | bluff
# Processing Record 25 of Set 4 | yinchuan
# Processing Record 26 of Set 4 | itarema
# Processing Record 27 of Set 4 | tramagal
# Processing Record 28 of Set 4 | sinop
# Processing Record 29 of Set 4 | hun
# Processing Record 30 of Set 4 | karratha
# Processing Record 31 of Set 4 | provideniya
# Processing Record 32 of Set 4 | tazovskiy
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | keetmanshoop
# Processing Record 35 of Set 4 | ipira
# Processing Record 36 of Set 4 | adre
# Processing Record 37 of Set 4 | tokmak
# Processing Record 38 of Set 4 | solvychegodsk
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | sarangani
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | srednekolymsk
# Processing Record 44 of Set 4 | neka
# Processing Record 45 of Set 4 | kitgum
# Processing Record 46 of Set 4 | fairbanks
# Processing Record 47 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 4 | galveston
# Processing Record 49 of Set 4 | aykhal
# Processing Record 50 of Set 4 | sitges
# Processing Record 1 of Set 5 | nadvoitsy
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | baishishan
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | san javier
# Processing Record 6 of Set 5 | ulladulla
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | lillooet
# Processing Record 9 of Set 5 | tarbagatay
# Processing Record 10 of Set 5 | deputatskiy
# Processing Record 11 of Set 5 | mahanoro
# Processing Record 12 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | korla
# Processing Record 15 of Set 5 | ambatondrazaka
# Processing Record 16 of Set 5 | denpasar
# Processing Record 17 of Set 5 | boston
# Processing Record 18 of Set 5 | faya
# Processing Record 19 of Set 5 | katherine
# Processing Record 20 of Set 5 | bontang
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | tautira
# Processing Record 24 of Set 5 | astghadzor
# Processing Record 25 of Set 5 | umm lajj
# Processing Record 26 of Set 5 | tucumcari
# Processing Record 27 of Set 5 | luwuk
# Processing Record 28 of Set 5 | tilichiki
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | souillac
# Processing Record 32 of Set 5 | nantong
# Processing Record 33 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 5 | debre birhan
# Processing Record 35 of Set 5 | ust-omchug
# Processing Record 36 of Set 5 | barrow
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | ha noi
# Processing Record 39 of Set 5 | tateyama
# Processing Record 40 of Set 5 | ponta delgada
# Processing Record 41 of Set 5 | ternate
# Processing Record 42 of Set 5 | batangafo
# Processing Record 43 of Set 5 | teguise
# Processing Record 44 of Set 5 | turkmenabat
# Processing Record 45 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 5 | marzuq
# Processing Record 49 of Set 5 | hirara
# Processing Record 50 of Set 5 | baykit
# Processing Record 1 of Set 6 | norman wells
# Processing Record 2 of Set 6 | priargunsk
# Processing Record 3 of Set 6 | saldanha
# Processing Record 4 of Set 6 | asyut
# Processing Record 5 of Set 6 | marevo
# Processing Record 6 of Set 6 | zhezkazgan
# Processing Record 7 of Set 6 | chipinge
# Processing Record 8 of Set 6 | kanniyakumari
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | henties bay
# Processing Record 12 of Set 6 | vila franca do campo
# Processing Record 13 of Set 6 | piacabucu
# Processing Record 14 of Set 6 | lavrentiya
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | kimbe
# Processing Record 19 of Set 6 | furano
# Processing Record 20 of Set 6 | cumana
# Processing Record 21 of Set 6 | carnarvon
# Processing Record 22 of Set 6 | vestmannaeyjar
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | kodinsk
# Processing Record 25 of Set 6 | nemuro
# Processing Record 26 of Set 6 | derzhavinsk
# Processing Record 27 of Set 6 | vila velha
# Processing Record 28 of Set 6 | codrington
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | ginir
# Processing Record 31 of Set 6 | kerrobert
# Processing Record 32 of Set 6 | zinder
# Processing Record 33 of Set 6 | yithion
# City not found. Skipping...
# Processing Record 34 of Set 6 | myitkyina
# Processing Record 35 of Set 6 | kyabe
# Processing Record 36 of Set 6 | chapar
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | hobyo
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | mayumba
# Processing Record 41 of Set 6 | russell
# Processing Record 42 of Set 6 | mar del plata
# Processing Record 43 of Set 6 | bara
# Processing Record 44 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 45 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | pochutla
# Processing Record 48 of Set 6 | dandong
# Processing Record 49 of Set 6 | porbandar
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 7 | powell
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | viransehir
# Processing Record 6 of Set 7 | north vernon
# Processing Record 7 of Set 7 | doha
# Processing Record 8 of Set 7 | dahegam
# Processing Record 9 of Set 7 | walvis bay
# Processing Record 10 of Set 7 | mogwase
# Processing Record 11 of Set 7 | san luis
# Processing Record 12 of Set 7 | san francisco
# Processing Record 13 of Set 7 | alofi
# Processing Record 14 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 7 | wote
# Processing Record 16 of Set 7 | the valley
# Processing Record 17 of Set 7 | la rioja
# Processing Record 18 of Set 7 | broken hill
# Processing Record 19 of Set 7 | lensk
# Processing Record 20 of Set 7 | pachino
# Processing Record 21 of Set 7 | general roca
# Processing Record 22 of Set 7 | amapa
# Processing Record 23 of Set 7 | brownsville
# Processing Record 24 of Set 7 | saint-leu
# Processing Record 25 of Set 7 | oktyabrskiy
# Processing Record 26 of Set 7 | fatima
# Processing Record 27 of Set 7 | port lincoln
# Processing Record 28 of Set 7 | nouakchott
# Processing Record 29 of Set 7 | xilitla
# Processing Record 30 of Set 7 | muswellbrook
# Processing Record 31 of Set 7 | gondanglegi
# Processing Record 32 of Set 7 | esperance
# Processing Record 33 of Set 7 | sungaipenuh
# Processing Record 34 of Set 7 | store heddinge
# Processing Record 35 of Set 7 | urusha
# Processing Record 36 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | kodiak
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | barda
# Processing Record 41 of Set 7 | namatanai
# Processing Record 42 of Set 7 | yarovoye
# Processing Record 43 of Set 7 | shenjiamen
# Processing Record 44 of Set 7 | mazagao
# Processing Record 45 of Set 7 | jiexiu
# Processing Record 46 of Set 7 | opotiki
# Processing Record 47 of Set 7 | kavaratti
# Processing Record 48 of Set 7 | richard toll
# City not found. Skipping...
# Processing Record 49 of Set 7 | batagay-alyta
# Processing Record 50 of Set 7 | kidal
# Processing Record 1 of Set 8 | ijero
# Processing Record 2 of Set 8 | tarifa
# Processing Record 3 of Set 8 | cayenne
# Processing Record 4 of Set 8 | chiang klang
# Processing Record 5 of Set 8 | george
# Processing Record 6 of Set 8 | katangli
# Processing Record 7 of Set 8 | carmen
# Processing Record 8 of Set 8 | zyryanka
# Processing Record 9 of Set 8 | peniche
# Processing Record 10 of Set 8 | marsh harbour
# Processing Record 11 of Set 8 | waingapu
# Processing Record 12 of Set 8 | gaziantep
# Processing Record 13 of Set 8 | nishihara
# Processing Record 14 of Set 8 | sorong
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | sioux lookout
# Processing Record 17 of Set 8 | sur
# Processing Record 18 of Set 8 | santa fe
# Processing Record 19 of Set 8 | allahganj
# Processing Record 20 of Set 8 | sakakah
# Processing Record 21 of Set 8 | kapuskasing
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | bay roberts
# Processing Record 24 of Set 8 | superior
# Processing Record 25 of Set 8 | viedma
# Processing Record 26 of Set 8 | narsaq
# Processing Record 27 of Set 8 | frontera
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | lata
# Processing Record 31 of Set 8 | sergeyevka
# Processing Record 32 of Set 8 | raudeberg
# Processing Record 33 of Set 8 | araouane
# Processing Record 34 of Set 8 | kirundo
# Processing Record 35 of Set 8 | cockburn town
# Processing Record 36 of Set 8 | grado
# Processing Record 37 of Set 8 | beringovskiy
# Processing Record 38 of Set 8 | arman
# Processing Record 39 of Set 8 | saint-francois
# Processing Record 40 of Set 8 | kutum
# Processing Record 41 of Set 8 | ngama
# Processing Record 42 of Set 8 | zaliznychne
# Processing Record 43 of Set 8 | aklavik
# Processing Record 44 of Set 8 | vicksburg
# Processing Record 45 of Set 8 | sucua
# Processing Record 46 of Set 8 | qandala
# Processing Record 47 of Set 8 | bilibino
# Processing Record 48 of Set 8 | glens falls
# Processing Record 49 of Set 8 | ancud
# Processing Record 50 of Set 8 | pasighat
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | anito
# Processing Record 3 of Set 9 | takoradi
# Processing Record 4 of Set 9 | zmievka
# City not found. Skipping...
# Processing Record 5 of Set 9 | marsa matruh
# Processing Record 6 of Set 9 | tanout
# Processing Record 7 of Set 9 | carballo
# Processing Record 8 of Set 9 | marsala
# Processing Record 9 of Set 9 | panaba
# Processing Record 10 of Set 9 | namibe
# Processing Record 11 of Set 9 | gajendragarh
# Processing Record 12 of Set 9 | uddevalla
# Processing Record 13 of Set 9 | maragogi
# Processing Record 14 of Set 9 | gogrial
# Processing Record 15 of Set 9 | sibolga
# Processing Record 16 of Set 9 | lixourion
# Processing Record 17 of Set 9 | vuktyl
# Processing Record 18 of Set 9 | kulhudhuffushi
# Processing Record 19 of Set 9 | palmer
# Processing Record 20 of Set 9 | zarate
# Processing Record 21 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 22 of Set 9 | manokwari
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | lyubashivka
# Processing Record 25 of Set 9 | empangeni
# Processing Record 26 of Set 9 | mezen
# Processing Record 27 of Set 9 | avera
# Processing Record 28 of Set 9 | konya
# Processing Record 29 of Set 9 | muriwai beach
# Processing Record 30 of Set 9 | ostrovnoy
# Processing Record 31 of Set 9 | pajarito
# Processing Record 32 of Set 9 | bogovarovo
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | preobrazheniye
# Processing Record 35 of Set 9 | kalmar
# Processing Record 36 of Set 9 | toora-khem
# Processing Record 37 of Set 9 | horta
# Processing Record 38 of Set 9 | tianpeng
# Processing Record 39 of Set 9 | biak
# Processing Record 40 of Set 9 | kushima
# Processing Record 41 of Set 9 | myaundzha
# Processing Record 42 of Set 9 | kloulklubed
# Processing Record 43 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 44 of Set 9 | aras
# Processing Record 45 of Set 9 | port hardy
# Processing Record 46 of Set 9 | barcelos
# Processing Record 47 of Set 9 | colares
# Processing Record 48 of Set 9 | asau
# Processing Record 49 of Set 9 | york
# Processing Record 50 of Set 9 | nortelandia
# Processing Record 1 of Set 10 | kattivakkam
# Processing Record 2 of Set 10 | tera
# Processing Record 3 of Set 10 | kondinskoye
# Processing Record 4 of Set 10 | caravelas
# Processing Record 5 of Set 10 | constitucion
# Processing Record 6 of Set 10 | seydi
# Processing Record 7 of Set 10 | potma
# City not found. Skipping...
# Processing Record 8 of Set 10 | sirur
# Processing Record 9 of Set 10 | saint-augustin
# Processing Record 10 of Set 10 | acapulco
# Processing Record 11 of Set 10 | belyy yar
# Processing Record 12 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 10 | portel
# Processing Record 14 of Set 10 | gloversville
# Processing Record 15 of Set 10 | galle
# Processing Record 16 of Set 10 | ceres
# Processing Record 17 of Set 10 | grindavik
# Processing Record 18 of Set 10 | kaeo
# Processing Record 19 of Set 10 | westport
# Processing Record 20 of Set 10 | ponta grossa
# Processing Record 21 of Set 10 | huilong
# Processing Record 22 of Set 10 | morehead
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | linhares
# Processing Record 25 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 10 | itoman
# Processing Record 27 of Set 10 | muisne
# Processing Record 28 of Set 10 | churapcha
# Processing Record 29 of Set 10 | sambo creek
# Processing Record 30 of Set 10 | banda aceh
# Processing Record 31 of Set 10 | burgeo
# Processing Record 32 of Set 10 | valparaiso
# Processing Record 33 of Set 10 | kontagora
# Processing Record 34 of Set 10 | kerouane
# Processing Record 35 of Set 10 | bilma
# Processing Record 36 of Set 10 | college
# Processing Record 37 of Set 10 | syracuse
# Processing Record 38 of Set 10 | aberdeen
# Processing Record 39 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 10 | yaan
# Processing Record 41 of Set 10 | labuhan
# Processing Record 42 of Set 10 | colesberg
# Processing Record 43 of Set 10 | vila
# Processing Record 44 of Set 10 | talnakh
# Processing Record 45 of Set 10 | road town
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | shetpe
# Processing Record 48 of Set 10 | lar
# Processing Record 49 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 50 of Set 10 | saint-pierre
# Processing Record 1 of Set 11 | sobolevo
# Processing Record 2 of Set 11 | mehamn
# Processing Record 3 of Set 11 | krasnoselkup
# Processing Record 4 of Set 11 | beira
# Processing Record 5 of Set 11 | shitanjing
# Processing Record 6 of Set 11 | inirida
# Processing Record 7 of Set 11 | tabou
# Processing Record 8 of Set 11 | elko
# Processing Record 9 of Set 11 | peterborough
# Processing Record 10 of Set 11 | tuatapere
# Processing Record 11 of Set 11 | kraksaan
# Processing Record 12 of Set 11 | roura
# Processing Record 13 of Set 11 | freeport
# Processing Record 14 of Set 11 | mayor pablo lagerenza
# Processing Record 15 of Set 11 | jieshi
# Processing Record 16 of Set 11 | candido mendes
# Processing Record 17 of Set 11 | lloydminster
# Processing Record 18 of Set 11 | dzaoudzi
# Processing Record 19 of Set 11 | tasiilaq
# Processing Record 20 of Set 11 | kedrovyy
# Processing Record 21 of Set 11 | natal
# Processing Record 22 of Set 11 | eldorado
# Processing Record 23 of Set 11 | birjand
# Processing Record 24 of Set 11 | americo brasiliense
# Processing Record 25 of Set 11 | mabaruma
# Processing Record 26 of Set 11 | samarai
# Processing Record 27 of Set 11 | zaozerne
# Processing Record 28 of Set 11 | koundara
# Processing Record 29 of Set 11 | carahue
# Processing Record 30 of Set 11 | fort nelson
# Processing Record 31 of Set 11 | iranshahr
# Processing Record 32 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 11 | havre
# Processing Record 34 of Set 11 | sao jose da coroa grande
# Processing Record 35 of Set 11 | jiazi
# Processing Record 36 of Set 11 | broome
# Processing Record 37 of Set 11 | katsuura
# Processing Record 38 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 39 of Set 11 | diamantino
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | ossora
# Processing Record 42 of Set 11 | baiyin
# Processing Record 43 of Set 11 | yenagoa
# Processing Record 44 of Set 11 | acari
# Processing Record 45 of Set 11 | sao mateus
# Processing Record 46 of Set 11 | carndonagh
# Processing Record 47 of Set 11 | anadyr
# Processing Record 48 of Set 11 | angoche
# Processing Record 49 of Set 11 | nanortalik
# Processing Record 50 of Set 11 | soure
# Processing Record 1 of Set 12 | ilinskiy
# Processing Record 2 of Set 12 | chara
# Processing Record 3 of Set 12 | saint anthony
# Processing Record 4 of Set 12 | sabang
# Processing Record 5 of Set 12 | robertsport
# Processing Record 6 of Set 12 | jutai
# Processing Record 7 of Set 12 | mnogovershinnyy
# Processing Record 8 of Set 12 | tolaga bay
# Processing Record 9 of Set 12 | morada nova
# Processing Record 10 of Set 12 | baturite
# Processing Record 11 of Set 12 | hargeysa
# Processing Record 12 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 12 | qesarya
# Processing Record 14 of Set 12 | xambioa
# Processing Record 15 of Set 12 | tura
# Processing Record 16 of Set 12 | coracao de jesus
# Processing Record 17 of Set 12 | richards bay
# Processing Record 18 of Set 12 | laguna
# Processing Record 19 of Set 12 | ust-kuyga
# Processing Record 20 of Set 12 | auki
# Processing Record 21 of Set 12 | graciano sanchez
# Processing Record 22 of Set 12 | bardstown
# Processing Record 23 of Set 12 | lasa
# Processing Record 24 of Set 12 | busovaca
# Processing Record 25 of Set 12 | luganville
# Processing Record 26 of Set 12 | piedras negras
# Processing Record 27 of Set 12 | tiarei
# Processing Record 28 of Set 12 | yarim
# Processing Record 29 of Set 12 | cortez
# Processing Record 30 of Set 12 | matara
# Processing Record 31 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 12 | mineiros
# Processing Record 33 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 34 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 35 of Set 12 | eureka
# Processing Record 36 of Set 12 | agirish
# Processing Record 37 of Set 12 | pontes e lacerda
# Processing Record 38 of Set 12 | manakara
# Processing Record 39 of Set 12 | buta
# Processing Record 40 of Set 12 | omboue
# Processing Record 41 of Set 12 | kalmunai
# Processing Record 42 of Set 12 | mugur-aksy
# Processing Record 43 of Set 12 | balykshi
# City not found. Skipping...
# Processing Record 44 of Set 12 | marshall
# Processing Record 45 of Set 12 | havoysund
# Processing Record 46 of Set 12 | pevek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 546

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kupino  54.37   77.30     64.38        66          48       11.70
# 1    Port Maria  18.37  -76.89     88.00        80           7        8.01
# 2    Georgetown   5.41  100.34     82.40        88          20        3.36
# 3        Castro -24.79  -50.01     68.22        59           7        7.52
# 4       Mataura -46.19  168.86     39.00        83          55        3.00
# 5   East London -33.02   27.91     55.62        65          83       23.96
# 6  Punta Arenas -53.15  -70.92     39.20        80          75       16.11
# 7         Lagoa  39.05  -27.98     69.71        78           0       13.53
# 8      Luderitz -26.65   15.16     64.40        39           0       18.34
# 9       Kavieng  -2.57  150.80     82.08        71         100        6.17
#
#   Country Current Description  Rain (inches)  Snow (inches)
# 0      RU    scattered clouds           0.00              0
# 1      JM           clear sky           0.00              0
# 2      MY          few clouds           0.00              0
# 3      BR           clear sky           0.00              0
# 4      NZ       broken clouds           0.00              0
# 5      ZA          light rain           0.46              0
# 6      CL       broken clouds           0.00              0
# 7      PT           clear sky           0.00              0
# 8      NA           clear sky           0.00              0
# 9      PG     overcast clouds           0.00              0

# %%
# Reorder columns.
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp",
                 "Humidity", "Cloudiness", "Wind Speed", "Current Description",
                 "Rain (inches)", "Snow (inches)"]]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kupino      RU  54.37   77.30     64.38        66          48
# 1    Port Maria      JM  18.37  -76.89     88.00        80           7
# 2    Georgetown      MY   5.41  100.34     82.40        88          20
# 3        Castro      BR -24.79  -50.01     68.22        59           7
# 4       Mataura      NZ -46.19  168.86     39.00        83          55
# 5   East London      ZA -33.02   27.91     55.62        65          83
# 6  Punta Arenas      CL -53.15  -70.92     39.20        80          75
# 7         Lagoa      PT  39.05  -27.98     69.71        78           0
# 8      Luderitz      NA -26.65   15.16     64.40        39           0
# 9       Kavieng      PG  -2.57  150.80     82.08        71         100
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0       11.70    scattered clouds           0.00              0
# 1        8.01           clear sky           0.00              0
# 2        3.36          few clouds           0.00              0
# 3        7.52           clear sky           0.00              0
# 4        3.00       broken clouds           0.00              0
# 5       23.96          light rain           0.46              0
# 6       16.11       broken clouds           0.00              0
# 7       13.53           clear sky           0.00              0
# 8       18.34           clear sky           0.00              0
# 9        6.17     overcast clouds           0.00              0

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Rain (inches)          float64
# Snow (inches)            int64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)']>0]
raining_cities
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 5    East London      ZA -33.02   27.91     55.62        65          83
# 16      Flinders      AU -34.58  150.86     53.01        83          90
# 28        Albany      US  42.60  -73.97     82.99        47           0
# 29    Svay Rieng      KH  11.09  105.80     79.92        86         100
# 38    Butaritari      KI   3.07  172.79     81.50        75         100
# ..           ...     ...    ...     ...       ...       ...         ...
# 509  Robertsport      LR   6.75  -11.37     74.10        92         100
# 518         Tura      IN  25.52   90.22     75.42        96         100
# 533       Matara      LK   5.95   80.54     80.78        86          99
# 536      Agirish      RU  61.92   63.02     63.99        89          63
# 542   Mugur-Aksy      RU  50.35   90.50     48.99        87         100
#
#      Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 5         23.96            light rain           0.46              0
# 16         5.01            light rain           0.51              0
# 28         9.13            light rain           0.21              0
# 29         6.08            light rain           0.47              0
# 38         8.99         moderate rain           1.77              0
# ..          ...                   ...            ...            ...
# 509       20.24  heavy intensity rain           6.97              0
# 518        6.91            light rain           0.48              0
# 533        8.86            light rain           0.11              0
# 536        6.46            light rain           0.89              0
# 542        4.38  heavy intensity rain           4.80              0
#
# [79 rows x 11 columns]

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)']>0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
